# %% [markdown]
# # **Use Catalog Workspace**

# %%
# %sql
USE CATALOG workspace

# %% [markdown]
# # **Create Lakehouse Schema**

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze
COMMENT 'Bromze layer: Raw ingested data';

CREATE SCHEMA IF NOT EXISTS silver
COMMENT 'Silver layer: Cleaned, standardized data';

CREATE SCHEMA IF NOT EXISTS gold
COMMENT 'Gold layer: Business-ready data';

# %% [markdown]
# # **Create Volume**

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.bronze.data_sources
COMMENT 'Volume for all data sources';
